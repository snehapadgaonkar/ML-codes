# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
import random

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  0.889886 -1.757402  1.513599 -1.511522 -1.890004       1
# 1  0.906237  0.674148 -1.161093 -0.953430  1.654903       0
# 2 -0.538969 -0.449020  0.609580 -1.880441 -0.404959       1
# 3 -0.399485  2.031956  0.086124 -1.417569  0.389324       1
# 4  0.653105 -0.853521  0.473013 -2.330958 -1.900314       1

# %%
# function for row sampling

def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
df.shape[0]
# Out:
# 100

# %%
df1=sample_rows(df,0.2)

# %%
df1
# Out:
#         col1      col2      col3      col4      col5  target
# 25  1.207307  1.526836 -0.497519 -1.480987  1.730340       0
# 22  0.942641  1.150261 -0.385737 -2.090157  2.413648       0
# 45  1.189505 -1.917800 -0.144581 -2.355322 -2.035800       1
# 92  2.278717 -4.163647  2.133982  0.314522 -1.237305       1
# 81 -3.224638  1.007943  2.261635 -0.087480  0.446554       0
# 14 -3.246213  2.063916  3.581184 -1.680546  0.441275       0
# 62 -2.024010  2.391344  1.224352 -0.510711  0.630611       0
# 71 -0.025208  1.317964 -0.003800 -1.311197  2.008152       0
# 43  1.305218 -0.697040  1.911925 -0.642030 -1.433632       1
# 25  1.207307  1.526836 -0.497519 -1.480987  1.730340       0
# 92  2.278717 -4.163647  2.133982  0.314522 -1.237305       1
# 64 -0.408807  0.871652  0.611853 -1.492841  0.707860       0
# 54 -1.377399  3.150161 -0.019649 -0.256705  1.230023       0
# 44  2.340500 -1.390602 -0.197909 -1.738121 -2.381813       1
# ...

# %%
df2=sample_rows(df,0.2)

# %%
df2
# Out:
#         col1      col2      col3      col4      col5  target
# 65 -0.384332 -0.250166 -0.369700 -4.545173 -3.091054       1
# 54 -1.377399  3.150161 -0.019649 -0.256705  1.230023       0
# 18  2.822286 -2.635666  0.501658  0.460207 -0.573083       1
# 59 -1.092753  2.342176  2.025510 -1.109291  0.295542       0
# 20 -1.583682  0.437026  0.002550 -0.042882  1.309136       0
# 55 -0.403481  1.674547 -0.716447 -0.510688  1.811055       0
# 85  0.985118  0.019605  2.067616 -0.132250 -0.626756       1
# 49 -2.201855  1.232082  1.270551 -0.536676  1.611431       0
# 28  2.398535 -0.686083  1.307961 -0.137244 -1.509359       0
# 32 -1.034649  0.637010  1.119447 -0.802690  1.211555       0
# 29  0.179622  1.019967  0.619939 -0.913016 -0.373393       0
# 50  1.212676 -1.523088  0.365504 -1.093532 -0.875316       1
# 72  1.048272  0.649394  0.346922 -1.346929 -1.054457       1
# 48  0.159942 -3.124491  3.929438  0.152015 -0.711269       1
# ...

# %%
df3=sample_rows(df,0.2)

# %%
df3
# Out:
#         col1      col2      col3      col4      col5  target
# 25  1.207307  1.526836 -0.497519 -1.480987  1.730340       0
# 36  1.263923 -0.867453  0.388766 -0.310624 -0.054744       1
# 75 -3.565929  0.806200  2.765274 -0.950862  1.057355       0
# 41 -0.708757  1.648040  0.270466 -1.567229  2.377254       0
# 40 -0.539018  0.643322  1.099810 -1.198055  1.140676       0
# 87 -0.802327 -1.078761  0.537989 -0.740338  0.979151       0
# 49 -2.201855  1.232082  1.270551 -0.536676  1.611431       0
# 87 -0.802327 -1.078761  0.537989 -0.740338  0.979151       0
# 54 -1.377399  3.150161 -0.019649 -0.256705  1.230023       0
# 40 -0.539018  0.643322  1.099810 -1.198055  1.140676       0
# 86 -2.398414  3.226095  3.164936 -1.703822  1.163938       0
# 73  0.070331  0.286104  1.974893 -1.418708 -1.328785       1
# 35  3.114612 -3.717065  1.994255  1.570148 -0.516896       1
# 12 -0.726813  1.270450  0.312410 -1.309259  3.123935       0
# ...

# %%
df1.shape
# Out:
# (20, 6)

# %%
df2.shape
# Out:
# (20, 6)

# %%
df3.shape
# Out:
# (20, 6)

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.75, 'x[4] <= 0.169\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.6, 0.875, 'x[4] <= -0.473\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.4, 0.625, 'x[0] <= 2.085\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.5, 0.75, 'True  '),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.6, 0.375, 'x[1] <= -1.661\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.7, 0.75, '  False')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.75, 'x[4] <= 0.288\ngini = 0.375\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.625, 0.5, '  False')]

# %%
clf1.predict(np.array([-1.053999,2.303948,-1.206537,-1.306676,3.045619]).reshape(1,5))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
feature_names = ['col1', 'col2', 'col3', 'col4', 'col5']
X_input = pd.DataFrame(np.array([-1.053999, 2.303948, -1.206537, -1.306676, 3.045619]).reshape(1, 5), columns=feature_names)
clf1.predict(X_input)
# Out:
# array([0])

# %%
clf2.predict(np.array([-1.053999,2.303948,-1.206537,-1.306676,3.045619]).reshape(1,5))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.053999,2.303948,-1.206537,-1.306676,3.045619]).reshape(1,5))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import random

def sample_features(df, percent):
    cols = random.sample(df.columns.tolist()[:-1], int(percent * (df.shape[1] - 1)))
    new_df = df[cols].copy()  # Explicitly create a copy to avoid the warning
    new_df['target'] = df.loc[:, 'target']  # Use .loc[] to avoid the SettingWithCopyWarning
    return new_df

def combined_sampling(df, row_percent, col_percent):
    new_df = sample_rows(df, row_percent)
    return sample_features(new_df, col_percent)

# %%
df1=sample_features(df,0.8)

# %%
df1
# Out:
#         col3      col1      col5      col4  target
# 0   1.513599  0.889886 -1.890004 -1.511522       1
# 1  -1.161093  0.906237  1.654903 -0.953430       0
# 2   0.609580 -0.538969 -0.404959 -1.880441       1
# 3   0.086124 -0.399485  0.389324 -1.417569       1
# 4   0.473013  0.653105 -1.900314 -2.330958       1
# ..       ...       ...       ...       ...     ...
# 95  0.119879  0.581307  1.122826 -1.261708       0
# 96  1.728633  1.187068 -1.420292 -0.781671       1
# 97 -1.345933  1.181004 -2.320651 -3.195161       1
# 98  2.166012 -1.205551 -0.718150 -1.855860       1
# 99  0.240306  0.997224 -0.497849 -1.013684       1
#
# [100 rows x 5 columns]

# %%
df2=sample_features(df,0.8)

# %%
df2
# Out:
#         col5      col2      col3      col4  target
# 0  -1.890004 -1.757402  1.513599 -1.511522       1
# 1   1.654903  0.674148 -1.161093 -0.953430       0
# 2  -0.404959 -0.449020  0.609580 -1.880441       1
# 3   0.389324  2.031956  0.086124 -1.417569       1
# 4  -1.900314 -0.853521  0.473013 -2.330958       1
# ..       ...       ...       ...       ...     ...
# 95  1.122826  4.143795  0.119879 -1.261708       0
# 96 -1.420292 -1.134062  1.728633 -0.781671       1
# 97 -2.320651 -0.116694 -1.345933 -3.195161       1
# 98 -0.718150  0.950350  2.166012 -1.855860       1
# 99 -0.497849  0.038416  0.240306 -1.013684       1
#
# [100 rows x 5 columns]

# %%
df3=sample_features(df,0.8)

# %%
df3
# Out:
#         col4      col1      col2      col3  target
# 0  -1.511522  0.889886 -1.757402  1.513599       1
# 1  -0.953430  0.906237  0.674148 -1.161093       0
# 2  -1.880441 -0.538969 -0.449020  0.609580       1
# 3  -1.417569 -0.399485  2.031956  0.086124       1
# 4  -2.330958  0.653105 -0.853521  0.473013       1
# ..       ...       ...       ...       ...     ...
# 95 -1.261708  0.581307  4.143795  0.119879       0
# 96 -0.781671  1.187068 -1.134062  1.728633       1
# 97 -3.195161  1.181004 -0.116694 -1.345933       1
# 98 -1.855860 -1.205551  0.950350  2.166012       1
# 99 -1.013684  0.997224  0.038416  0.240306       1
#
# [100 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:4],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:4],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:4],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.9375, 'x[2] <= 0.21\ngini = 0.499\nsamples = 100\nvalue = [52, 48]'),
#  Text(0.2222222222222222, 0.8125, 'x[1] <= -0.63\ngini = 0.183\nsamples = 49\nvalue = [5, 44]'),
#  Text(0.3611111111111111, 0.875, 'True  '),
#  Text(0.1111111111111111, 0.6875, 'x[2] <= -0.567\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.05555555555555555, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16666666666666666, 0.5625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3333333333333333, 0.6875, 'x[0] <= 0.615\ngini = 0.122\nsamples = 46\nvalue = [3, 43]'),
#  Text(0.2777777777777778, 0.5625, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.3888888888888889, 0.5625, 'x[3] <= -1.954\ngini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(0.3333333333333333, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4444444444444444, 0.4375, 'x[0] <= 0.624\ngini = 0.153\nsamples = 24\nvalue = [2, 22]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.9, 'x[0] <= 0.21\ngini = 0.499\nsamples = 100\nvalue = [52, 48]'),
#  Text(0.25, 0.7, 'x[1] <= 0.967\ngini = 0.183\nsamples = 49\nvalue = [5, 44]'),
#  Text(0.375, 0.8, 'True  '),
#  Text(0.125, 0.5, 'x[2] <= 1.274\ngini = 0.085\nsamples = 45\nvalue = [2, 43]'),
#  Text(0.0625, 0.3, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.1875, 0.3, 'x[2] <= 1.39\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.125, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.25, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.375, 0.5, 'x[0] <= -0.479\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3125, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4375, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.75, 0.7, 'x[3] <= 0.214\ngini = 0.145\nsamples = 51\nvalue = [47, 4]'),
#  Text(0.625, 0.8, '  False'),
#  Text(0.625, 0.5, 'x[0] <= 0.415\ngini = 0.042\nsamples = 47\nvalue = [46, 1]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.4875, 0.9285714285714286, 'x[2] <= 0.56\ngini = 0.499\nsamples = 100\nvalue = [52, 48]'),
#  Text(0.175, 0.7857142857142857, 'x[1] <= -0.615\ngini = 0.341\nsamples = 55\nvalue = [12, 43]'),
#  Text(0.33125, 0.8571428571428572, 'True  '),
#  Text(0.125, 0.6428571428571429, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.225, 0.6428571428571429, 'x[3] <= -0.866\ngini = 0.156\nsamples = 47\nvalue = [4, 43]'),
#  Text(0.1, 0.5, 'x[0] <= -2.386\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.05, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.15, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.35, 0.5, 'x[1] <= 2.37\ngini = 0.091\nsamples = 42\nvalue = [2, 40]'),
#  Text(0.25, 0.35714285714285715, 'x[0] <= -1.996\ngini = 0.051\nsamples = 38\nvalue = [1, 37]'),
#  Text(0.2, 0.21428571428571427, 'x[3] <= 0.894\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col3', 'col1', 'col5', 'col4', 'target'], dtype='object')
# Index(['col5', 'col2', 'col3', 'col4', 'target'], dtype='object')
# Index(['col4', 'col1', 'col2', 'col3', 'target'], dtype='object')

# %%
df3
# Out:
#         col4      col1      col2      col3  target
# 0  -1.511522  0.889886 -1.757402  1.513599       1
# 1  -0.953430  0.906237  0.674148 -1.161093       0
# 2  -1.880441 -0.538969 -0.449020  0.609580       1
# 3  -1.417569 -0.399485  2.031956  0.086124       1
# 4  -2.330958  0.653105 -0.853521  0.473013       1
# ..       ...       ...       ...       ...     ...
# 95 -1.261708  0.581307  4.143795  0.119879       0
# 96 -0.781671  1.187068 -1.134062  1.728633       1
# 97 -3.195161  1.181004 -0.116694 -1.345933       1
# 98 -1.855860 -1.205551  0.950350  2.166012       1
# 99 -1.013684  0.997224  0.038416  0.240306       1
#
# [100 rows x 5 columns]

# %%
clf1.predict(np.array([2.053996,-0.884838,1.620851,0.847292]).reshape(1,4))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([2.053996,-0.884838,1.620851,0.847292]).reshape(1,4))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([2.053996,-0.884838,1.620851,0.847292]).reshape(1,4))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df1 = combined_sampling(df,0.5,0.5)

# %%
df2 = combined_sampling(df,0.5,0.5)

# %%
df3 = combined_sampling(df,0.5,0.5)

# %%
df1
# Out:
#         col2      col3  target
# 9   1.482433  0.773851       0
# 62  2.391344  1.224352       0
# 20  0.437026  0.002550       0
# 33  1.807729  1.246936       0
# 31 -1.024347  0.220332       0
# 6  -2.356287  1.465392       1
# 71  1.317964 -0.003800       0
# 77  0.509043 -0.623178       1
# 79 -4.080358  4.217953       1
# 84  3.507729  4.308122       0
# 86  3.226095  3.164936       0
# 14  2.063916  3.581184       0
# 40  0.643322  1.099810       0
# 25  1.526836 -0.497519       0
# 52 -1.478242 -2.619136       1
# 56 -1.182941 -1.203690       0
# 78  1.786222  1.183998       0
# 69  1.478116  0.124106       0
# 4  -0.853521  0.473013       1
# 98  0.950350  2.166012       1
# 67 -2.584850  0.715871       1
# 21 -0.479438  0.060248       1
# 35 -3.717065  1.994255       1
# 23 -2.950346  1.137481       1
# 82  0.069742  1.239809       1
# 9   1.482433  0.773851       0
# 45 -1.917800 -0.144581       1
# 41  1.648040  0.270466       0
# 44 -1.390602 -0.197909       1
# ...

# %%
df2
# Out:
#         col4      col1  target
# 99 -1.013684  0.997224       1
# 25 -1.480987  1.207307       0
# 18  0.460207  2.822286       1
# 17 -0.590230 -1.509377       0
# 73 -1.418708  0.070331       1
# 80 -1.281546  1.804502       1
# 89 -2.710647  0.299948       1
# 71 -1.311197 -0.025208       0
# 41 -1.567229 -0.708757       0
# 33 -0.247343 -2.087070       0
# 40 -1.198055 -0.539018       0
# 54 -0.256705 -1.377399       0
# 51 -0.648595 -2.959566       0
# 81 -0.087480 -3.224638       0
# 83 -1.427559 -1.911327       0
# 91 -2.175546 -0.496853       0
# 69 -1.408284  0.335222       0
# 16 -1.885037  1.994045       1
# 22 -2.090157  0.942641       0
# 14 -1.680546 -3.246213       0
# 96 -0.781671  1.187068       1
# 72 -1.346929  1.048272       1
# 4  -2.330958  0.653105       1
# 59 -1.109291 -1.092753       0
# 94 -1.968508  1.416845       0
# 74 -1.266164  0.407245       1
# 17 -0.590230 -1.509377       0
# 11  0.258780  2.311918       1
# 76 -0.677300 -2.830356       0
# ...

# %%
df3
# Out:
#         col4      col3  target
# 22 -2.090157 -0.385737       0
# 37 -0.754072  2.128124       1
# 18  0.460207  0.501658       1
# 66 -1.259018  1.769236       0
# 41 -1.567229  0.270466       0
# 60 -0.240880  0.635907       1
# 82 -0.580044  1.239809       1
# 55 -0.510688 -0.716447       0
# 86 -1.703822  3.164936       0
# 8  -1.754657  1.164005       1
# 90 -3.554029 -0.324824       1
# 66 -1.259018  1.769236       0
# 65 -4.545173 -0.369700       1
# 33 -0.247343  1.246936       0
# 76 -0.677300  1.770028       0
# 48  0.152015  3.929438       1
# 36 -0.310624  0.388766       1
# 60 -0.240880  0.635907       1
# 82 -0.580044  1.239809       1
# 22 -2.090157 -0.385737       0
# 33 -0.247343  1.246936       0
# 93 -1.847969  0.858851       1
# 77 -2.578299 -0.623178       1
# 16 -1.885037  1.748106       1
# 79  1.167155  4.217953       1
# 85 -0.132250  2.067616       1
# 57 -1.276157  1.856581       0
# 81 -0.087480  2.261635       0
# 4  -2.330958  0.473013       1
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col2', 'col3', 'target'], dtype='object')
# Index(['col4', 'col1', 'target'], dtype='object')
# Index(['col4', 'col3', 'target'], dtype='object')

# %%
df3
# Out:
#         col4      col3  target
# 22 -2.090157 -0.385737       0
# 37 -0.754072  2.128124       1
# 18  0.460207  0.501658       1
# 66 -1.259018  1.769236       0
# 41 -1.567229  0.270466       0
# 60 -0.240880  0.635907       1
# 82 -0.580044  1.239809       1
# 55 -0.510688 -0.716447       0
# 86 -1.703822  3.164936       0
# 8  -1.754657  1.164005       1
# 90 -3.554029 -0.324824       1
# 66 -1.259018  1.769236       0
# 65 -4.545173 -0.369700       1
# 33 -0.247343  1.246936       0
# 76 -0.677300  1.770028       0
# 48  0.152015  3.929438       1
# 36 -0.310624  0.388766       1
# 60 -0.240880  0.635907       1
# 82 -0.580044  1.239809       1
# 22 -2.090157 -0.385737       0
# 33 -0.247343  1.246936       0
# 93 -1.847969  0.858851       1
# 77 -2.578299 -0.623178       1
# 16 -1.885037  1.748106       1
# 79  1.167155  4.217953       1
# 85 -0.132250  2.067616       1
# 57 -1.276157  1.856581       0
# 81 -0.087480  2.261635       0
# 4  -2.330958  0.473013       1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
df1.columns
# Out:
# Index(['col2', 'col3', 'target'], dtype='object')

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5666666666666667, 0.9285714285714286, 'x[0] <= 0.148\ngini = 0.493\nsamples = 50\nvalue = [28.0, 22.0]'),
#  Text(0.26666666666666666, 0.7857142857142857, 'x[0] <= -1.472\ngini = 0.384\nsamples = 27\nvalue = [7, 20]'),
#  Text(0.41666666666666663, 0.8571428571428572, 'True  '),
#  Text(0.2, 0.6428571428571429, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.3333333333333333, 0.6428571428571429, 'x[0] <= -0.939\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.2, 0.5, 'x[0] <= -1.287\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.13333333333333333, 0.35714285714285715, 'x[1] <= 0.559\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06666666666666667, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26666666666666666, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.5714285714285714, 0.95, 'x[1] <= -0.446\ngini = 0.493\nsamples = 50\nvalue = [28.0, 22.0]'),
#  Text(0.5, 0.85, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.5357142857142857, 0.8999999999999999, 'True  '),
#  Text(0.6428571428571429, 0.85, 'x[1] <= 1.598\ngini = 0.444\nsamples = 33\nvalue = [11, 22]'),
#  Text(0.6071428571428572, 0.8999999999999999, '  False'),
#  Text(0.5, 0.75, 'x[1] <= 1.197\ngini = 0.496\nsamples = 22\nvalue = [10, 12]'),
#  Text(0.42857142857142855, 0.65, 'x[1] <= 0.97\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.35714285714285715, 0.55, 'x[1] <= 0.78\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.2857142857142857, 0.45, 'x[1] <= 0.65\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.21428571428571427, 0.35, 'x[1] <= 0.499\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.14285714285714285, 0.25, 'x[0] <= -1.413\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.25, 0.9444444444444444, 'x[0] <= -2.211\ngini = 0.493\nsamples = 50\nvalue = [22.0, 28.0]'),
#  Text(0.16666666666666666, 0.8333333333333334, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.20833333333333331, 0.8888888888888888, 'True  '),
#  Text(0.3333333333333333, 0.8333333333333334, 'x[1] <= 0.628\ngini = 0.497\nsamples = 41\nvalue = [22, 19]'),
#  Text(0.29166666666666663, 0.8888888888888888, '  False'),
#  Text(0.16666666666666666, 0.7222222222222222, 'x[0] <= -0.411\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.08333333333333333, 0.6111111111111112, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.25, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.7222222222222222, 'x[1] <= 1.243\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.4166666666666667, 0.6111111111111112, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
# ...

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf1)
# Out:
# [Text(0.5666666666666667, 0.9285714285714286, 'x[0] <= 0.148\ngini = 0.493\nsamples = 50\nvalue = [28.0, 22.0]'),
#  Text(0.26666666666666666, 0.7857142857142857, 'x[0] <= -1.472\ngini = 0.384\nsamples = 27\nvalue = [7, 20]'),
#  Text(0.41666666666666663, 0.8571428571428572, 'True  '),
#  Text(0.2, 0.6428571428571429, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.3333333333333333, 0.6428571428571429, 'x[0] <= -0.939\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.2, 0.5, 'x[0] <= -1.287\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.13333333333333333, 0.35714285714285715, 'x[1] <= 0.559\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06666666666666667, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.26666666666666666, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.5714285714285714, 0.95, 'x[1] <= -0.446\ngini = 0.493\nsamples = 50\nvalue = [28.0, 22.0]'),
#  Text(0.5, 0.85, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.5357142857142857, 0.8999999999999999, 'True  '),
#  Text(0.6428571428571429, 0.85, 'x[1] <= 1.598\ngini = 0.444\nsamples = 33\nvalue = [11, 22]'),
#  Text(0.6071428571428572, 0.8999999999999999, '  False'),
#  Text(0.5, 0.75, 'x[1] <= 1.197\ngini = 0.496\nsamples = 22\nvalue = [10, 12]'),
#  Text(0.42857142857142855, 0.65, 'x[1] <= 0.97\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.35714285714285715, 0.55, 'x[1] <= 0.78\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.2857142857142857, 0.45, 'x[1] <= 0.65\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.21428571428571427, 0.35, 'x[1] <= 0.499\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.14285714285714285, 0.25, 'x[0] <= -1.413\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.25, 0.9444444444444444, 'x[0] <= -2.211\ngini = 0.493\nsamples = 50\nvalue = [22.0, 28.0]'),
#  Text(0.16666666666666666, 0.8333333333333334, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.20833333333333331, 0.8888888888888888, 'True  '),
#  Text(0.3333333333333333, 0.8333333333333334, 'x[1] <= 0.628\ngini = 0.497\nsamples = 41\nvalue = [22, 19]'),
#  Text(0.29166666666666663, 0.8888888888888888, '  False'),
#  Text(0.16666666666666666, 0.7222222222222222, 'x[0] <= -0.411\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.08333333333333333, 0.6111111111111112, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.25, 0.6111111111111112, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5, 0.7222222222222222, 'x[1] <= 1.243\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.4166666666666667, 0.6111111111111112, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
# ...

# %%
df3
# Out:
#         col4      col3  target
# 22 -2.090157 -0.385737       0
# 37 -0.754072  2.128124       1
# 18  0.460207  0.501658       1
# 66 -1.259018  1.769236       0
# 41 -1.567229  0.270466       0
# 60 -0.240880  0.635907       1
# 82 -0.580044  1.239809       1
# 55 -0.510688 -0.716447       0
# 86 -1.703822  3.164936       0
# 8  -1.754657  1.164005       1
# 90 -3.554029 -0.324824       1
# 66 -1.259018  1.769236       0
# 65 -4.545173 -0.369700       1
# 33 -0.247343  1.246936       0
# 76 -0.677300  1.770028       0
# 48  0.152015  3.929438       1
# 36 -0.310624  0.388766       1
# 60 -0.240880  0.635907       1
# 82 -0.580044  1.239809       1
# 22 -2.090157 -0.385737       0
# 33 -0.247343  1.246936       0
# 93 -1.847969  0.858851       1
# 77 -2.578299 -0.623178       1
# 16 -1.885037  1.748106       1
# 79  1.167155  4.217953       1
# 85 -0.132250  2.067616       1
# 57 -1.276157  1.856581       0
# 81 -0.087480  2.261635       0
# 4  -2.330958  0.473013       1
# ...

# %%
clf1.predict(np.array([1.827990,-3.037736]).reshape(1,2))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([1.827990,-3.037736]).reshape(1,2))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([1.827990,-3.037736]).reshape(1,2))
# Out:
# c:\Users\meetu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
